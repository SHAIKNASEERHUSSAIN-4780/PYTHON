# %% [markdown]
# ### 2D Graphics

# %% [markdown]
# ##### Point and Line

# %%
import matplotlib.pyplot as plt
plt.plot(3, 2)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(3, 2, 'ro')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(3, 2, 'or')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [2, 4, 6, 8, 10]
y = [3, 5, 7, 9, 11]
plt.plot(x, y, 'ro')
plt.show()
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [2, 4, 6, 8, 10]
y = [3, 5, 7, 9, 11]
plt.plot(x, y, 'r*--')
plt.show()

# %%
import matplotlib.pyplot as plt
y = [3, 5, 7, 9, 11]
plt.plot(y)
plt.show()
x = [2, 4, 6, 8, 10]
y = [3, 5, 7, 9, 11]
plt.plot(x, y, 'r*--', markersize = 10.5, linewidth = 2.2)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [2, 4, 6, 8, 10]
y = [3, 5, 7, 9, 11]
plt.plot(x, y, 'r*--', markersize = 10.5, linewidth = 2.2)
plt.axis([1, 11, 2, 12])
plt.show()

# %%
import matplotlib.pyplot as plt
x = [2, 4, 6, 8, 10]
y = [3, 5, 7, 9, 11]
plt.plot(x, y, 'r*--', markersize = 10.5, linewidth = 2.2)
plt.axis([1, 11, 2, 12])
plt.xlabel("X")
plt.ylabel("X * X")
plt.title("X vs X * X")
plt.grid()

# %%
import matplotlib.pyplot as plt
def plotFunctions(a, b, step):
    '''
    Objective: To plot functions f(x) = x**2 and f(x) = x**3 in the same figure
    Input Parameter: a, b, step - numeric value
    Return Value: None
    '''
    nSteps = int((b - a)/step)
    x = [a + step * i for i in range(nSteps+1)]
    y1 = [t**2 for t in x]
    y2 = [t**3 for t in x]
    plt.plot(x, y1, 'ro--', label = 'X vs X**2')
    plt.plot(x, y2, 'ro--', label = 'X vs x**3')
    plt.legend()
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('X vs X**2 and X vs X**3')
    plt.grid()
    plt.show()
def main():
    '''
    Objective: To plot two functions on same graph based on user input
    Input Parameter: None
    Return Value: None
    '''
    a = float(input("Enter first element of the range: "))
    b = float(input("Enter last element of the range: "))
    step = float(input("Enter step size: "))
    plotFunctions(a, b, step)
if __name__ == "__main__":
    main()
# Out:
# Enter first element of the range:  2.5
# Enter last element of the range:  4.5
# Enter step size:  0.1

# %%
import matplotlib.pyplot as plt
def plotFunctions(x):
    '''
    Objective: To plot functions f(x) = X, 
    f(x) = x**2, f(x) = x**3, 
    f(x) = x**4, f(x) = x**5, and
    f(x) = x**6 in different plots on same graph
    Input Parameter: x - list
    Return Value: None
    '''
    y1 = [i**1 for i in x]
    y2 = [i**2 for i in x]
    y3 = [i**3 for i in x]
    y4 = [i**4 for i in x]
    y5 = [i**5 for i in x]
    y6 = [i**6 for i in x]
    plt.subplot(2, 3, 1)
    plt.plot(x, y1, 'ro--')
    plt.xlabel('X')
    plt.ylabel('X')
    plt.title('X vs X')
    plt.grid()
    plt.subplot(2, 3, 2)
    plt.plot(x, y2, 'b*--')
    plt.xlabel('X')
    plt.ylabel('X**2')
    plt.title('X vs X**2')
    plt.grid()
    plt.subplot(2, 3, 3)
    plt.plot(x, y3, 'g*--')
    plt.xlabel('X')
    plt.ylabel('X**3')
    plt.title('X vs X**3')
    plt.grid()
    plt.subplot(2, 3, 4)
    plt.plot(x, y4, 'kx:')
    plt.xlabel('X')
    plt.ylabel('X**4')
    plt.title('X vs X**4')
    plt.grid()
    plt.subplot(2, 3, 5)
    plt.plot(x, y5, 'mv--')
    plt.xlabel('X')
    plt.ylabel('X**5')
    plt.title('X vs X**5')
    plt.grid()
    plt.subplot(2, 3, 6)
    plt.plot(x, y6, 'cp--')
    plt.xlabel('X')
    plt.ylabel('X**6')
    plt.title('X vs X**6')
    plt.grid()
    plt.tight_layout()
    plt.show()
def main():
    '''
    Objective: To plot six functions in different plots on same graph based on user input
    Input Parameter: None
    Return Value: None
    '''
    a = eval(input("Enter list x to be plotted: "))
    plotFunctions(x)
if __name__ =="__main__":
    main()
# Out:
# Enter list x to be plotted:  (1, 15)

# %% [markdown]
# ### Histogram and Pi Chart
# - A histogram is used to represent the frequency of various values in a data set using bars, also known as bins.

# %% [markdown]
# ##### Histogram

# %%
import matplotlib.pyplot as plt
def plotHistogram(data):
    '''
    Objective: To plot a histogram
    Input Parameter: data - list
    Return Parameter: None
    '''
    plt.hist(data)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title("Histogram")
    # For setting limits of x axis
    plt.xlim(min(data) - 1, max(data) + 1)
    plt.show()
def main():
    '''
    Objective: To plot a histogram based on user input
    Input Parameter: None
    Return Value: None
    '''
    data = list(map(int, input("Enter the data to be plotted as histogram: ").split()))
    plotHistogram(data)
if __name__ == "__main__":
    main()
# Out:
# Enter the data to be plotted as histogram:  1 1 4 4 1 2 2 3 3 3 4 4 4 6

# %%
import matplotlib.pyplot as plt
def plotHist(data):
    '''
    Objective: To plot a histogram with different bins boundaries.
    Input Parameter: data - list
    Return Value: None
    '''
    plt.hist(data, bins = [i - 0.5 for i in range(0, max(data) + 2)])
    plt.xlabel("value")
    plt.ylabel("Frequency")
    plt.title("Histogram")
    plt.xlim(min(data) - 1, max(data) + 1)
def main():
    '''
    Objective: To plot a histogram with different bins boundaries
    Input Parameter: None
    Return Value: None
    '''
    data = list(map(int, input("Enter the data to be plotted for histogram").split()))
    plotHist(data)
if __name__ == "__main__":
    main()
# Out:
# Enter the data to be plotted for histogram 1 1 4 4 1 2 2 3 3 3 4 4 4 6

# %% [markdown]
# ##### Pie chart

# %%
import matplotlib.pyplot as plt
def plotPieChart(data, labels):
    '''
    Objective: To plot a pie chart
    Input Parameter: data, labels - list
    Return Value: None
    '''
    plt.pie(data, labels = labels, autopct = '%.2f')
    plt.title("Pie Chart")
    plt.show()
def main():
    '''
    Objective: To plot a pie chart
    Input Parameter: None
    Return Value: None
    '''
    data = list(map(int, input("Enter data to be plotted as pie chart: ").split()))
    labels = list(map(str, input("Enter the labels: ").split()))
    plotPieChart(data, labels)
if __name__ == "__main__":
    main()
# Out:
# Enter data to be plotted as pie chart:  30 40 90 50
# Enter the labels:  'VolleyBall' 'Hockey' 'Cricket' 'Badminton'

# %% [markdown]
# ### Sine and Cosine Curves

# %%
from matplotlib.pyplot import *
from math import *
def sineCurve():
    '''
    Objective: To plot a sine function
    Input Parameter: None
    Return Value: None
    '''
    subplot(2, 1, 1)
    degrees = range(0, 360 + 1)
    sineValues = [sin(radians(i)) for i in degrees]
    plot(degrees, sineValues)
    xlabel('Degree')
    ylabel('Sine Value')
    title('Sine Curve')
    grid()
    show()
def coseCurve():
    '''
    Objective: To plot a cose function
    Input Parameter: None
    Return Value: None
    '''
    subplot(2, 1, 1)
    degrees = range(0, 360 + 1)
    coseValues = [cos(radians(i)) for i in degrees]
    plot(degrees, coseValues)
    xlabel("Degree")
    ylabel("Cosine Value")
    title("Cosine Value")
    grid()
    show()
def main():
    '''
    Objective: To plot sine and cose curves
    Input Parameter: None
    Return Value: None
    '''
    sineCurve()
    coseCurve()
    tight_layout()
if __name__ == "__main__":
    main()

# %% [markdown]
# ### Graphical Objects: Circle, Ellipse, Rectangle, Polygon, and Arrow

# %% [markdown]
# ##### Circle

# %%
from matplotlib.pyplot import *
from matplotlib.patches import *
def circle(radius):
    '''
    Objective: To plot a circle of given radius
    Input Parameter: radius - numeric
    Return Value: None
    '''
    circle = Circle((0, 0), radius, facecolor='green', edgecolor='red', linestyle='dotted', linewidth=2.2)
    gca().add_patch(circle)
    axis('scaled')
    title('Circle')
    show()
def main():
    '''
    Objective: To plot a circle based on user input
    Input Parameter: None
    REturn Value: None
    '''
    radius = float(input("Enter the radius: "))
    circle(radius)
if __name__ == "__main__":
    main()
# Out:
# Enter the radius:  4

# %% [markdown]
# ##### Ellipse

# %%
from matplotlib.pyplot import *
from matplotlib.patches import *
def plotEllipse(width, height):
    '''
    Objective: To plot an ellipse of given width and height
    Input Parameter: width, height - numeric
    Return Value: None
    '''
    ellipse = Ellipse((0, 0), width, height, angle = 15, facecolor = 'cyan', edgecolor = 'red', linestyle = 'dashed', linewidth = 2.2)
    gca().add_patch(ellipse)
    axis('scaled')
    title('Ellipse')
    show()
def main():
    '''
    Objective: To plot an ellipse based on user input
    Input Parameter: None
    Return Value: None
    '''
    width = float(input("Enter the width: "))
    height = float(input("Enter the height: "))
    plotEllipse(width, height)
if __name__ == "__main__":
    main()
# Out:
# Enter the width:  5
# Enter the height:  3

# %% [markdown]
# ##### Rectangle

# %%
from matplotlib.pyplot import *
from matplotlib.patches import *
def plotRectangle(length, breadth):
    '''
    Objective: To plot a rectangle of lenght and breadth
    Input Parameters: lenght and breadth - numeric
    Return Value: None
    '''
    rectangle = Rectangle((0, 0), length, breadth, facecolor = 'green', edgecolor = 'red', linestyle = 'dashed', linewidth = 2.2)
    gca().add_patch(rectangle)
    axis('scaled')
    title('Rectangle')
    show()
def main():
    '''
    Objective: To plot a rectangle based on user input
    Input Parameter: None
    Return Value: None
    '''
    length = float(input("Enter the length: "))
    breadth = float(input("Enter the breadth: "))
    plotRectangle(length, breadth)
if __name__ == "__main__":
    main()
# Out:
# Enter the length:  6
# Enter the breadth:  3

# %% [markdown]
# ##### Polygon

# %%
from matplotlib.pyplot import *
from matplotlib.patches import *
def plotPolygon(points):
    '''
    Objective: To plot a polygon joining given a list of points
    Input Parameter: points - list
    Return Value: None
    '''
    polygon = Polygon(points, ec = 'red', linestyle = 'dashdot', lw = 2.2)
    gca().add_patch(polygon)
    axis('scaled')
    title('Polygon')
    show()
def main():
    ''''
    Objective: To plot a polygon based on user input
    Input Parameter: None
    Return Value: None
    '''
    points = eval(input("Enter the points: "))
    plotPolygon(points)
if __name__ == "__main__":
    main()
# Out:
# Enter the points:  [(2, 2), (3, 4), (4, 2), (5, 4), (6, 2), (4, 1)]

# %% [markdown]
# ##### Arrows

# %%
from matplotlib.pyplot import *
from matplotlib.patches import *
def plotArrow(pos, dx, dy):
    '''
    Objective: To plot an arrow beginning base position pos (x, y) and ending the head position defined by dx and dy relative to the badde of the arrow
    Input Parameters: pos, dx, dy - numeric
    Retrn Value: None
    '''
    x, y = pos[0], pos[1]
    arrow = Arrow(x, y, dx, dy, fill = False, hatch = 'O')
    gca().add_patch(arrow)
    axis('scaled')
    title("Arrow")
    show()
def main():
    '''
    Objective: To plot an arrow based on user input
    Input Parameter: None
    Return Value: None
    '''
    pos = tuple(map(float, input("Enter the starting position (x, y): ").split()))
    dx = float(input("Enter the dx: "))
    dy = float(input("Enter the dy: "))
    plotArrow(pos, dx, dy)
if __name__ == "__main__":
    main()
# Out:
# Enter the starting position (x, y):  1 2
# Enter the dx:  -1
# Enter the dy:  3

# %% [markdown]
# ### 3D Objects

# %% [markdown]
# ##### Box

# %%
from vpython import *
box(size = vector(7,4,5), color = color.green, opacity = 0.25)

# %% [markdown]
# ##### Sphere

# %%
from vpython import *
sphere(pos = vector(0, 0, 0), radius = 0.6, color = color.cyan, opacity = 0.75, shineness = 0.1)

# %% [markdown]
# ##### Ring

# %%
from vpython import *
ring(axis = vector(0.5, 0, 0.9), radius = 0.5, thickness = 0.15)

# %% [markdown]
# ##### Cylinder

# %%
from vpython import *
cylinder(pos = vector(-2, 2, 1), axis = vector(5, 0, 5), radius = 2)

# %% [markdown]
# ##### Arrow

# %%
from vpython import *
arrow(pos = vector(-3, 0, 0), axis = vector(5, 2, 0), shaftwidth = 0.5, color = color.yellow, up = vector(0, 10, 20))

# %% [markdown]
# ##### Cone

# %%
from vpython import *
cone(pos = vector(0, -2, 0), axis = vector(0, 4, 0), radius = 2)

# %% [markdown]
# ##### Curve

# %%
from vpython import *
curve(pos = [(-2, -2, 0), (-2, 0, 1), (0, 0, 0), (3, 0, 0), (2, 1, 0), (3, 4, 2)], radius = 0.05)

# %% [markdown]
# ### Animation - Bouncing Ball

# %%
from vpython import *
ground = box(size = vector(10, 0.1, 10), color = color.white)
ball = sphere(pos = vector(0, 4, 0), radius = 1, color = color.yellow)
scene.center = vector(0, 5, 5)
velocity = 10
e = 0.9 # coefficient of restitution
dt = 0.01
while True:
    rate(300) # Indicates number of loop per sec
    prevPos = ball.pos.y  # Access the y component of the position vector
    ball.pos.y += velocity * dt  # Update the y component of the position vector
    if ball.pos.y < ball.radius:
        velocity = -velocity * e
        ball.pos.y = ball.radius
    if (prevPos - ball.pos.y) == 0:
        break
    velocity = velocity - 9.81*dt
