# %% [markdown]
# ### Multi-threading
# -  Threading allows multiple tasks run concurrently.
# -  Thread makes application performance more faster.
# -  Thread is a functionality or logic which can be executed simultaneously along with other part of program.
# -  Thread is a pre-defined class defined in the threading module.

# %%
import threading
from time import *

class Thread1(threading.Thread):
    def run(self):
        for i in range(50):
            print("Python")
class Thread2(threading.Thread):
    def run(self):
        for i in range(50):
            print("Java")

t1 = Thread1()
t2 = Thread2()

t1.start()
sleep(0.3)
t2.start()
# Out:
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Python
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
# Java
